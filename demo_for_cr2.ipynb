# %%
# Import necessary libraries
import pennylane as qml
from pennylane import numpy as np
import lpenny
# Use the alias 'lpenny' for imports from your custom library
from lpenny.pot_gen_1d import *           
          
from lpenny.dvr_vqe import *               
from lpenny.greedy_search_algorithm import GreedyCircs

# %%
mol_params = cr2_params
params = [5.2, 9]
N = 5
spin = 13

cr2_dvr_options = { 'type': '1d',
        'box_lims': (params[0], params[1]),
        'dx': (params[1] - params[0]) / (2**N),
        'count':(2**N)
        } 

h_dvr =  gen_ham(mol_params, spin, cr2_dvr_options)
h_dvr_pd = qml.pauli_decompose(h_dvr)
print(h_dvr_pd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mol_params = cr2_params
#       2 params = [5.2, 9]
#       3 N = 5
#
# NameError: name 'cr2_params' is not defined

# %%
ansatz_options_list = {
    'type': 'greedy',
    'constructive': True,
    'layers': 18,
    'num_keep': 6,
    'num_qubits': 5,
    'add_h': True,
    'add_sx': True,
    'add_rs': True,
    'samples': 100, 
    'reps': 2,
    'max_gate': 20
    }

vqe_options_list = {
    'step size': 0.5,
    'max_iterations': 1000,
}
g = GreedyCircs(ansatz_options_list, h_dvr_pd, N)
g.greedy_vqe(ansatz_options_list, )
# Out:
# Circuit number:  0
#  0: ──H──SX──RZ(0.00)─╭ECR──────┤ ╭<𝓗>
#  1: ──H──SX──RZ(0.00)─│────╭ECR─┤ ├<𝓗>
#  2: ──H──SX──RZ(0.00)─│────╰ECR─┤ ├<𝓗>
#  3: ──H──SX──RZ(0.00)─│─────────┤ ├<𝓗>
#  4: ──H──SX──RZ(0.00)─│─────────┤ ╰<𝓗>
# -1: ──────────────────╰ECR──────┤
# Circuit number:  1
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  2
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  3
# 0: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  4
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  5
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  6
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  7
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  8
# 0: ──H──SX──RZ(0.00)─────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──SX─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  9
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  10
# 0: ──H──SX──RZ(0.00)──────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─╭ECR─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─╰ECR─┤ ╰<𝓗>
# Circuit number:  11
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  12
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  13
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  14
# 0: ──H──SX──RZ(0.00)──────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─╭ECR─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─╰ECR─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──────┤ ╰<𝓗>
# Circuit number:  15
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  16
# 0: ──H──SX──RZ(0.00)─────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──SX─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  17
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  18
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  19
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  20
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  21
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  22
# 0: ──H──SX──RZ(0.00)─────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──SX─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  23
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  24
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  25
# 0: ──H──SX──RZ(0.00)──SX───────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  26
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  27
#  0: ──H──SX──RZ(0.00)─╭ECR───────────┤ ╭<𝓗>
#  1: ──H──SX──RZ(0.00)─│─────RZ(0.00)─┤ ├<𝓗>
#  2: ──H──SX──RZ(0.00)─│──────────────┤ ├<𝓗>
#  3: ──H──SX──RZ(0.00)─│──────────────┤ ├<𝓗>
#  4: ──H──SX──RZ(0.00)─│──────────────┤ ╰<𝓗>
# -1: ──────────────────╰ECR───────────┤
# Circuit number:  28
# 0: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  29
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  30
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  31
# 0: ──H──SX──RZ(0.00)──────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─╭ECR─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─╰ECR─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──────┤ ╰<𝓗>
# Circuit number:  32
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  33
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  34
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  35
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──SX───────┤ ╰<𝓗>
# Circuit number:  36
# 0: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  37
#  0: ──H──SX──RZ(0.00)─╭ECR─────┤ ╭<𝓗>
#  1: ──H──SX──RZ(0.00)─│────────┤ ├<𝓗>
#  2: ──H──SX──RZ(0.00)─│────────┤ ├<𝓗>
#  3: ──H──SX──RZ(0.00)─│────────┤ ├<𝓗>
#  4: ──H──SX──RZ(0.00)─│─────SX─┤ ╰<𝓗>
# -1: ──────────────────╰ECR─────┤
# Circuit number:  38
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  39
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  40
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  41
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  42
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  43
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  44
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  45
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  46
# 0: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  47
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  48
# 0: ──H──SX──RZ(0.00)─╭ECR─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─╰ECR─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──────┤ ╰<𝓗>
# Circuit number:  49
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  50
# 0: ──H──SX──RZ(0.00)─────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──SX─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  51
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  52
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  53
# 0: ──H──SX──RZ(0.00)──SX───────╭ECR─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────╰ECR─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)────────────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──RZ(0.00)──────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)────────────────┤ ╰<𝓗>
# Circuit number:  54
# 0: ──H──SX──RZ(0.00)─╭ECR─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─╰ECR─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──────┤ ╰<𝓗>
# Circuit number:  55
# 0: ──H──SX──RZ(0.00)──SX─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  56
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  57
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  58
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  59
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  60
# 0: ──H──SX──RZ(0.00)─────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──SX─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  61
# 0: ──H──SX──RZ(0.00)─────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──SX─┤ ╰<𝓗>
# Circuit number:  62
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  63
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  64
# 0: ──H──SX──RZ(0.00)─────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──SX─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  65
# 0: ──H──SX──RZ(0.00)──────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─╭ECR─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─╰ECR─┤ ╰<𝓗>
# Circuit number:  66
# 0: ──H──SX──RZ(0.00)─────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──SX─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  67
# 0: ──H──SX──RZ(0.00)──SX─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──SX─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  68
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  69
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  70
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  71
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  72
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  73
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  74
# 0: ──H──SX──RZ(0.00)──────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─╭ECR─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─╰ECR─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──────┤ ╰<𝓗>
# Circuit number:  75
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  76
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  77
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  78
# 0: ──H──SX──RZ(0.00)──SX─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──SX─┤ ╰<𝓗>
# Circuit number:  79
# 0: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  80
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  81
# 0: ──H──SX──RZ(0.00)──────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─╭ECR─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─╰ECR─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──────┤ ╰<𝓗>
# Circuit number:  82
# 0: ──H──SX──RZ(0.00)──────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─╭ECR─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─╰ECR─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──────┤ ╰<𝓗>
# Circuit number:  83
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  84
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  85
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  86
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  87
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  88
# 0: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  89
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  90
# 0: ──H──SX──RZ(0.00)──────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─╭ECR─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─╰ECR─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──────┤ ╰<𝓗>
# Circuit number:  91
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  92
# 0: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  93
# 0: ──H──SX──RZ(0.00)───────────┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)───────────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)───────────┤ ╰<𝓗>
# Circuit number:  94
#  0: ──H──SX──RZ(0.00)─╭ECR──────┤ ╭<𝓗>
#  1: ──H──SX──RZ(0.00)─│─────────┤ ├<𝓗>
#  2: ──H──SX──RZ(0.00)─│────╭ECR─┤ ├<𝓗>
#  3: ──H──SX──RZ(0.00)─│────╰ECR─┤ ├<𝓗>
#  4: ──H──SX──RZ(0.00)─│─────────┤ ╰<𝓗>
# -1: ──────────────────╰ECR──────┤
# Circuit number:  95
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  96
# 0: ──H──SX──RZ(0.00)──SX─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─────┤ ╰<𝓗>
# Circuit number:  97
# 0: ──H──SX──RZ(0.00)─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)─┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)─┤ ╰<𝓗>
# Circuit number:  98
# 0: ──H──SX──RZ(0.00)─╭ECR─┤ ╭<𝓗>
# 1: ──H──SX──RZ(0.00)─╰ECR─┤ ├<𝓗>
# 2: ──H──SX──RZ(0.00)──SX──┤ ├<𝓗>
# 3: ──H──SX──RZ(0.00)──────┤ ├<𝓗>
# 4: ──H──SX──RZ(0.00)──────┤ ╰<𝓗>
# Circuit number:  99
#  0: ──H──SX──RZ(0.00)─╭ECR─────┤ ╭<𝓗>
#  1: ──H──SX──RZ(0.00)─│────────┤ ├<𝓗>
#  2: ──H──SX──RZ(0.00)─│─────SX─┤ ├<𝓗>
#  3: ──H──SX──RZ(0.00)─│────────┤ ├<𝓗>
#  4: ──H──SX──RZ(0.00)─│────────┤ ╰<𝓗>
# -1: ──────────────────╰ECR─────┤

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(circ_list[0, 1])
#
# TypeError: list indices must be integers or slices, not tuple

# %%
# import jax
# import pennylane as qml
# import random
# from pennylane import numpy as np
# import optax

# import pennylane as qml
# from pennylane.templates import SimplifiedTwoDesign

# jax.config.update("jax_platform_name", "cpu")
# jax.config.update('jax_enable_x64', True)

# hartree_to_cm = 219474.66

# wires = [0, 1, 2, 3, 4]   
# # Define the quantum device
# dev_ideal = qml.device("lightning.qubit", wires=wires)
# @qml.qnode(dev_ideal)
# def circuit_generator1(params, wires=wires):
#     import pennylane as qml
# from pennylane import numpy as np

# # Number of qubits
# num_qubits = 5

# # Initialize a device
# dev = qml.device('default.qubit', wires=num_qubits)

# # Quantum circuit definition
# @qml.qnode(dev)
# def ansatz(params):
#     # Apply RY gates to all qubits
#     for i in range(num_qubits):
#         qml.RY(params[i], wires=i)

#     # Apply the CNOTs and RYs in the pattern shown in the image
#     for i in range(num_qubits - 1):
#         qml.CNOT(wires=[i, i + 1])
#         qml.RY(params[i + num_qubits], wires=i + 1)

#     # Repeat the pattern
#     for i in reversed(range(num_qubits - 1)):
#         qml.CNOT(wires=[i, i + 1])
#         qml.RY(params[i + 2*num_qubits - 1], wires=i)

#     return qml.expval(h_dvr_pd)


#   # make sure h_dvr_pd is a valid observable

# thetas = np.array(np.zeros(19), requires_grad=True)

# def cost_fn(params, wires=wires):
#     return ansatz(params, shots=4000)
# # Optimization parameters
# max_iterations = 5000

# opt = optax.amsgrad(learning_rate=0.01)

# # Optimization loop
# energy = []
# angle = []

# opt_state = opt.init(thetas)

# for n in range(max_iterations+1):
#     # Use JAX to calculate the gradient
#     gradient = jax.grad(cost_fn)(thetas)
#     updates, opt_state = opt.update(gradient, opt_state, thetas)
#     thetas = optax.apply_updates(thetas, updates)
    
#     # Save the angles and energy values
#     angle.append(thetas.copy())
#     energy.append(cost_fn(thetas))
    
#     # Print the step and energy
#     print(f"Step = {n},  Energy = {energy[-1]:.8f} cm^-1")

# %%
print(angle[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(angle[-1])
#
# NameError: name 'angle' is not defined

# %%
# def circuit(params, gate_sequence):
#     for gate in gate_sequence:
#         if gate == 'RZ':
#             qml.RZ(params.pop(0), wires=0)  # Example applying RZ with a parameter to wire 0
#         elif gate == 'SX':
#             qml.SX(wires=0)
#         elif gate == 'PauliX':
#             qml.PauliX(wires=1)
#         elif gate == 'ECR':
#             qml.ECR(wires=[0, 1])

# %%
energies = np.array(energy)
energies = energies
print(energies)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
y = -548.68
sns.set_theme(style="whitegrid", palette="husl")
sns.lineplot(energies, legend='full')
plt.axhline(y=y, color='r', linestyle='--', label=fr'Target Energy 1 ({y} cm$^{-1}$)')
plt.xlabel('Iteration (# of steps)')
plt.legend()
plt.ylabel(r'Energy (cm$^{-1}$)')
plt.title('Energy Convergence')
plt.show()
